# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahzhongg/IS4200-Final-Project/blob/main/reranking_IS4200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# download libraries
import os
# !apt-get install openjdk-21-jre-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-21-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-21-openjdk-amd64/bin/java
# !java -version
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from google.colab import drive
# Out:
# openjdk version "21.0.6" 2025-01-21
# OpenJDK Runtime Environment (build 21.0.6+7-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 21.0.6+7-Ubuntu-122.04.1, mixed mode, sharing)

# %%
# read in wordcount pkl files
drive.mount('/content/drive', force_remount=True)

pkl_folder = '/content/drive/My Drive/pkl files'
pkl_files = [os.path.join(pkl_folder, f) for f in os.listdir(pkl_folder)]

for pkl in pkl_files:
  print(pkl)
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/pkl files/social_media_word_counts.pkl
# /content/drive/My Drive/pkl files/metabolic_fasting_word_counts.pkl
# /content/drive/My Drive/pkl files/urbanization_wildfire_word_counts.pkl
# /content/drive/My Drive/pkl files/ethical_ai_query_word_counts.pkl
# /content/drive/My Drive/pkl files/genetic_engineering_word_counts.pkl
# /content/drive/My Drive/pkl files/smoking_query_word_counts.pkl
# /content/drive/My Drive/pkl files/battery_word_counts.pkl
# /content/drive/My Drive/pkl files/climate_change_word_counts.pkl

# %%
import pickle
path = '/content/drive/My Drive/pkl files'
topics = {'Effects of smoking on lung cancer': 'smoking_query_word_counts.pkl',
       'Ethical implications of AI': 'ethical_ai_query_word_counts.pkl',
       'Climate change and wildfires': 'climate_change_word_counts.pkl',
       'Effects of Fasting on Metabolic Health': 'metabolic_fasting_word_counts.pkl',
       'Psychological effects of social media on children and teens': 'social_media_word_counts.pkl',
       'Impacts of urbanization on wildlife biodiversity': 'urbanization_wildfire_word_counts.pkl',
       'Battery technology advancements for electric vehicles': 'battery_word_counts.pkl',
       'Genetic engineering as treatment for genetic disorders': 'genetic_engineering_word_counts.pkl'
       }

all_data = {}
# load query dict
for topic, filename in topics.items():
        full_path = os.path.join(path, filename)
        with open(full_path, "rb") as f:
          all_data[topic] = pickle.load(f)

# %%
len(all_data)
# Out:
# 8

# %%
# get doc for a given topic and then get 30 more irrelevant from diff topic to make and set that relevant to 0
def get_query_corpus(all_data, query):
  # doc for given query
  query_corpus = all_data[query]

  # get other docs for a query
  other_docs = {}
  for q, docs in all_data.items():
    if q != query:
      other_docs.update(docs)

  # randomly sample 30 keys from other_docs
  sampled_other_docs = np.random.choice(list(other_docs.keys()), 30, replace=False)

  # get sampled docs and update query_corpus with irrelevant and repalce values
  for key in sampled_other_docs:
    irrelevant_doc = other_docs[key]
    irrelevant_doc['relevance'] = 0 # update relevance to 0
    query_corpus[key] = (irrelevant_doc) # update in query_corpus

  return query_corpus

# %%
# create baseline rerank function
# import sentence transformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# import sentence transformer
sentence_transformer = SentenceTransformer('all-MiniLM-L6-v2')

def reranking_model(query):
  # this reranking model ONLY encodes using sentence transformer to calculate cosine similarity between query and docs + feel free to update with using other keys like citations/references/etc.
  query_corpus = get_query_corpus(all_data, query)
  doc_ids = list(query_corpus.keys())

  # get document tokens as list and convery to str to pass into sentence transformer encoder (cant pass in counter dict)
  document_tokens = [doc['tokens'] for doc in query_corpus.values()]

  def counter_to_str(counter):
    return ' '.join([token for token, freq in counter.items() for _ in range(freq)])

  document_str = [counter_to_str(counter) for counter in document_tokens]

  # encode
  query_embedding = sentence_transformer.encode(query)
  document_embeddings = sentence_transformer.encode(document_str)

  # calculate cosine similarity
  cosine_similarities = cosine_similarity([query_embedding], document_embeddings)[0]

  # get reranked list and rank in decending
  reranked = list(zip([str(doc_id) for doc_id in doc_ids], [float(score) for score in cosine_similarities]))
  reranked.sort(key=lambda x: x[1], reverse=True)
  return reranked


reranking_model('Effects of smoking on lung cancer')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# [('https://www.semanticscholar.org/paper/d1a4a81f2763d3a25a5ff4ca78713be79c60231b',
#   0.618094801902771),
#  ('https://www.semanticscholar.org/paper/73fe7c5b7635be9222e26a723384d3fc5717f02d',
#   0.5018330812454224),
#  ('https://www.semanticscholar.org/paper/76ded5364597a6b4abadd6a155f67b262c2c3f7c',
#   0.46484869718551636),
#  ('https://www.semanticscholar.org/paper/5cdc4a4dffe96963f6600c6bd422b2e0c8ae79c4',
#   0.44873547554016113),
#  ('https://www.semanticscholar.org/paper/7389668b7c32bcb662d42dbde25de03543f4ba6f',
#   0.4280984401702881),
#  ('https://www.semanticscholar.org/paper/dd81d8d9292d5da251299cc8c38c620a18125d1e',
#   0.42106887698173523),
#  ('https://www.semanticscholar.org/paper/0a6744c0aabf94d33399c22410f8a70e2742b5bd',
#   0.42106887698173523),
#  ('https://www.semanticscholar.org/paper/275749da6c8bfffd06c399b4cca4f8da3a57812a',
#   0.3729900121688843),
#  ('https://www.semanticscholar.org/paper/21c193ccdb94e6e54ee8ab03832282138b0684bb',
#   0.3624398708343506),
#  ('https://www.semanticscholar.org/paper/7425f3ca048b011e0680b1ad9c3df0d034a49ccc',
#   0.3476720452308655),
#  ('https://www.semanticscholar.org/paper/240596fd206f66f81b1704edec920931e22fc71a',
#   0.34468671679496765),
#  ('https://www.semanticscholar.org/paper/40afd0f8b34761ed9aaf77cb1e8c626613c41c61',
#   0.3353208303451538),
#  ('https://www.semanticscholar.org/paper/5bdf2035baffef92be6d649f9569560277b42d98',
#   0.3260610103607178),
#  ('https://www.semanticscholar.org/paper/c885a2969be04873fc53d6ebc809817f3a5f2f5f',
#   0.3195127248764038),
#  ('https://www.semanticscholar.org/paper/1b2b7abe2bf6ca7cd9f6c9d0a4dab894e34a54bc',
#   0.31869179010391235),
#  ('https://www.semanticscholar.org/paper/861af2586241e55a979e102db79acea9eaca2b11',
#   0.31193792819976807),
#  ('https://www.semanticscholar.org/paper/5531a4371535a6027b672e5bd598c9d79222f112',
#   0.3068069815635681),
#  ('https://www.semanticscholar.org/paper/087e018ae1d95e1799e24f9e17cdcd56af84a522',
#   0.27761414647102356),
#  ('https://www.semanticscholar.org/paper/1376df0751944d34c7bf8b04c2eb16b7fc221a6d',
#   0.2665400207042694),
#  ('https://www.semanticscholar.org/paper/9759acf5c798f2b817779d5bf55ea28904737864',
#   0.24204452335834503),
#  ('https://www.semanticscholar.org/paper/15e965058fb014d31296e6e0adcd9605198bcb14',
#   0.23285837471485138),
#  ('https://www.semanticscholar.org/paper/d579551d13892084e7f753c2177fe49d1ee92b32',
#   0.22170980274677277),
#  ('https://www.semanticscholar.org/paper/288733edb6fc7b954bcb4fbf430e9b5ba20bc5f8',
#   0.2124539464712143),
#  ('https://www.semanticscholar.org/paper/10cf5ba57728f06062351c19197d530cf92711a6',
#   0.19184018671512604),
#  ('https://www.semanticscholar.org/paper/3eb1676762ed2eb1525851116c88a617d8685119',
#   0.16769209504127502),
#  ('https://www.semanticscholar.org/paper/e6cc6233fcb6800d4570c872159c64857e428fbe',
#   0.16157494485378265),
#  ('https://www.semanticscholar.org/paper/1a0f1d0b49ab4997ad2d4519e26e0d154a963ed2',
#   0.15715746581554413),
#  ('https://www.semanticscholar.org/paper/6481130e1f4f91bc0daca74685845756ccac7766',
#   0.14467670023441315),
#  ('https://www.semanticscholar.org/paper/960e75207ba062e33b5e3d160f75981d7d26a434',
#   0.1446470320224762),
#  ('https://www.semanticscholar.org/paper/4b79bd312c9fdd2e5b7631e2aa514a7dc75bb820',
#   0.14313700795173645),
#  ('https://www.semanticscholar.org/paper/f52d8bb4a2f3d331e308cbf5c36fdab8c76682b0',
#   0.1420712023973465),
#  ('https://www.semanticscholar.org/paper/40450eee89bc5831bfe0d04fa4aaf5e724182d6a',
#   0.12742739915847778),
#  ('https://www.semanticscholar.org/paper/2e32f7a482a397cfa15a0edb6baba7b4d981dafa',
#   0.12377065420150757),
#  ('https://www.semanticscholar.org/paper/268600086ce7dfa282fae6e363d8c2674c906aa8',
#   0.12274646759033203),
#  ('https://www.semanticscholar.org/paper/4f4315c7b33831e545eaf84c0614c3fcf785203f',
#   0.12108780443668365),
#  ('https://www.semanticscholar.org/paper/13c3702c266c5806e6ec208c1d6460d920e0445f',
#   0.1155434101819992),
#  ('https://www.semanticscholar.org/paper/d4478ab412a6de1f5155e471e535bd31a1166180',
#   0.113547682762146),
#  ('https://www.semanticscholar.org/paper/a87fb6289a68262428e18aa44f9c10c0553e283e',
#   0.10976004600524902),
#  ('https://www.semanticscholar.org/paper/6a377e665665e02610758ae82c019c78b1c3d9d7',
#   0.09583160281181335),
#  ('https://www.semanticscholar.org/paper/95bdc6cd008aafd33fe07e0e019de6f316f7a901',
#   0.08939431607723236),
#  ('https://www.semanticscholar.org/paper/16ce73e2543ddac7af0f0023662cd8ad34e6256c',
#   0.088248610496521),
#  ('https://www.semanticscholar.org/paper/3b800c3a493f0430c5eb93aeb7936753c1523088',
#   0.08638428896665573),
#  ('https://www.semanticscholar.org/paper/80c1300633327fca8b2da0a5d89838857df9dded',
#   0.08532828092575073),
#  ('https://www.semanticscholar.org/paper/5ec9fe81653e210dde87aaa7880035c49e4c927c',
#   0.08394308388233185),
#  ('https://www.semanticscholar.org/paper/1343c3a6854f7dfbf047078068350cb2d45f525f',
#   0.0803878903388977),
#  ('https://www.semanticscholar.org/paper/41f39b6cef95da17ba7ce24369ab6bae2c244344',
#   0.07705817371606827),
#  ('https://www.semanticscholar.org/paper/e161c4c68618abd966ff3d362a2b91ca172a5cb7',
#   0.07272299379110336),
#  ('https://www.semanticscholar.org/paper/53210f5b115d63aac14f127e5041ab322d160157',
#   0.07216747105121613),
#  ('https://www.semanticscholar.org/paper/6ff89b62e1ffa490050db958abb43b32e1bacc24',
#   0.06767190992832184),
#  ('https://www.semanticscholar.org/paper/70c466bd385b23f4a78c43f088ede55b03f52b04',
#   0.06696168333292007),
#  ('https://www.semanticscholar.org/paper/38da1efbe76b1dde2d726f48a16902717968129b',
#   0.06324778497219086),
#  ('https://www.semanticscholar.org/paper/2d338a0e15102ec7f2f5e47d29abf9e9e167b97e',
#   0.06064879894256592),
#  ('https://www.semanticscholar.org/paper/699e446488c33bb5620d65843203c63fce22b497',
#   0.05965554714202881),
#  ('https://www.semanticscholar.org/paper/a2299ca622b5b6e8a6f3c631e0511e355378f277',
#   0.05585109815001488),
#  ('https://www.semanticscholar.org/paper/0a28758d2e1abda7760e2ebff6edf14572cb9b5f',
#   0.05262451618909836),
#  ('https://www.semanticscholar.org/paper/3cd31189682fb6dd2177da19c0c3ff3537666a7b',
#   0.05151631683111191),
#  ('https://www.semanticscholar.org/paper/cdba593e242cfe5e00a8c682e761e80d7ebf0ede',
#   0.05002466216683388),
#  ('https://www.semanticscholar.org/paper/20e13c41692f6fe26ab76c8d3750180193e8a71a',
#   0.050010621547698975),
#  ('https://www.semanticscholar.org/paper/8144771f91fa303bf8d7d9a95903fbf4b5c2e38a',
#   0.04954081028699875),
#  ('https://www.semanticscholar.org/paper/e61c4c248a97d10a1009139ceb27245ed4676cb1',
#   0.0492376983165741),
#  ('https://www.semanticscholar.org/paper/3e32467c10c841307027f0c070c78e73cc1aa3a4',
#   0.04441562667489052),
#  ('https://www.semanticscholar.org/paper/beda03ba614faa96fafb68fc7eafe32a23ba8613',
#   0.04315359145402908),
#  ('https://www.semanticscholar.org/paper/886b716a9e249b54f67defad0821eef798ae510a',
#   0.0427943617105484),
#  ('https://www.semanticscholar.org/paper/27cc74db5327c3ac71981621bb932bb14b4193c3',
#   0.03246668726205826),
#  ('https://www.semanticscholar.org/paper/8b1f2fb6e42a413a9cc770a7eb3be4a648b80bef',
#   0.026608116924762726),
#  ('https://www.semanticscholar.org/paper/b3aedeee136cb217c9c27d1102db1d23cc70742e',
#   0.025234736502170563),
#  ('https://www.semanticscholar.org/paper/81e361db4bee50cca747435f73eebed03cc2948a',
#   0.025084536522626877),
#  ('https://www.semanticscholar.org/paper/26f01b77c479555ab05066e2829b667d078e17b8',
#   0.02384183555841446),
#  ('https://www.semanticscholar.org/paper/601c944ace31a91fb9ceb50553df3663f9f55074',
#   0.02116410620510578),
#  ('https://www.semanticscholar.org/paper/74da8d77a7667cb89f5d916fe8fa837cfa0a19f2',
#   0.018729915842413902),
#  ('https://www.semanticscholar.org/paper/781ce8ad18e51bde11d0ee1446816ea55440e611',
#   0.018592316657304764),
#  ('https://www.semanticscholar.org/paper/e0ff8cea6e6c8c9bff7d5e079a9adefc5908cae6',
#   0.018531136214733124),
#  ('https://www.semanticscholar.org/paper/0d40b434318e7a7e562aff2b5cac1fea16b38a15',
#   0.012682192958891392),
#  ('https://www.semanticscholar.org/paper/bc351e9bf74e2b6ad6e2459e04d8fff43d17dd16',
#   0.00937928631901741),
#  ('https://www.semanticscholar.org/paper/103a831a72143606f5c6d2ba19e807970f1a7f4f',
#   0.008507355116307735),
#  ('https://www.semanticscholar.org/paper/79f1c7d67c8cc6a8f5e59d6bb078e983ed7b94c4',
#   0.005988554563373327),
#  ('https://www.semanticscholar.org/paper/cbc610e6679da8c1ab1d999ff2767401d2845191',
#   0.003253411501646042),
#  ('https://www.semanticscholar.org/paper/213807c86141298c0bbf82d230d29ebd0be3b136',
#   0.0026127060409635305),
#  ('https://www.semanticscholar.org/paper/72dde4438fc1b4cf93f3bee93ba386c629912273',
#   0.0008774362504482269),
#  ('https://www.semanticscholar.org/paper/8c73812d1dcc009722a385871b728d52b5cf5aaa',
#   -0.005049910396337509),
#  ('https://www.semanticscholar.org/paper/259c2aa09bd139f018e3cfd352cd6e49a141e704',
#   -0.005447644740343094),
#  ('https://www.semanticscholar.org/paper/87ee7fc89b3cf7318be05dbd35678cfc501ba289',
#   -0.007054267451167107),
#  ('https://www.semanticscholar.org/paper/aef362634349e5c756fac42c681c394b8cd7d291',
#   -0.008737914264202118),
#  ('https://www.semanticscholar.org/paper/096e515a15a6ad294557403486446d6b551052f4',
#   -0.009824639186263084),
#  ('https://www.semanticscholar.org/paper/7e32516ec04f6c6bad8f32bed5868301398622d1',
#   -0.009838253259658813),
#  ('https://www.semanticscholar.org/paper/8c4f2ad4ccdd7f0eb2e52f2747a726c6786a8a07',
#   -0.010614383965730667),
#  ('https://www.semanticscholar.org/paper/f590c90faa4fdcdd64d9c1f43ca52519c3cf93d2',
#   -0.010838164016604424),
#  ('https://www.semanticscholar.org/paper/7339563f11dbee03a247e427ee425f6360195a6e',
#   -0.011701421812176704),
#  ('https://www.semanticscholar.org/paper/5694c8ecaaf85d7a41968d61690bc8cf8ec3e977',
#   -0.01478218100965023),
#  ('https://www.semanticscholar.org/paper/b188f1cbe27f6eb26fd97540b99382f2654079ac',
#   -0.0149945467710495),
#  ('https://www.semanticscholar.org/paper/c2e2c6b0a74398d7fbcbe05c6568ea74bfcea56a',
#   -0.01648848131299019),
#  ('https://www.semanticscholar.org/paper/3e836ddbb4ea3ee30ff45e79ff2acbe4e339b35e',
#   -0.018022457137703896),
#  ('https://www.semanticscholar.org/paper/2877b325151ddd6eea962166677597f062e56502',
#   -0.019969280809164047),
#  ('https://www.semanticscholar.org/paper/123e5e35a32ac880b35ff6649fa10d372d520f01',
#   -0.020629730075597763),
#  ('https://www.semanticscholar.org/paper/e30e64e79bd36315d66c721be00264d9553eac6b',
#   -0.021316833794116974),
#  ('https://www.semanticscholar.org/paper/ab1625531c7de89b8b8b7d943657519807b41894',
#   -0.024376116693019867),
#  ('https://www.semanticscholar.org/paper/64fd11ed35bd9c7b3e1a20bfb6a4113a3e6793e1',
#   -0.024601250886917114),
#  ('https://www.semanticscholar.org/paper/161829192c550c3bf023d980ecd8dec3033d00da',
#   -0.026707058772444725),
#  ('https://www.semanticscholar.org/paper/91c77eb8f36ad628d6c6ef27a8a4a52c3b823f3a',
#   -0.02724025957286358),
#  ('https://www.semanticscholar.org/paper/d74caf2c7d2cf49e7d54ab937ec855e43255d848',
#   -0.028525402769446373),
#  ('https://www.semanticscholar.org/paper/bb110820acf4d492c996bc74acfb531bdc480f1b',
#   -0.03066674992442131),
#  ('https://www.semanticscholar.org/paper/d123c2c057f6c7552cf4b051dc94a992d0389ed9',
#   -0.03066674992442131),
#  ('https://www.semanticscholar.org/paper/c5be7ecba0a06c2f6e04dddd640e13197ed9324b',
#   -0.03230796754360199),
#  ('https://www.semanticscholar.org/paper/0ee63059447ba9754b846ec045d20794fb04932b',
#   -0.0346064567565918),
#  ('https://www.semanticscholar.org/paper/22bdb46a0caf007b2c92b3e2580cbde4d01cf947',
#   -0.035834383219480515),
#  ('https://www.semanticscholar.org/paper/c551254f2b83d50b0d9d5fba66dfa8c3c565569c',
#   -0.03616637364029884),
#  ('https://www.semanticscholar.org/paper/14f2d20105a97f91f0401641f0bdf0f26eb75e92',
#   -0.039382822811603546),
#  ('https://www.semanticscholar.org/paper/e26c8a9de11d60945af9d3c47c7f8c26d25443f1',
#   -0.03951860964298248),
#  ('https://www.semanticscholar.org/paper/07ea2bac239ce2021ef0172d9aef6d0d5d4e2be4',
#   -0.04629877582192421),
#  ('https://www.semanticscholar.org/paper/e1765eea26e3bc3d14816fb154c1beec89547659',
#   -0.046532586216926575),
#  ('https://www.semanticscholar.org/paper/b04f42e9c8fbf170ad88d3234510809858f0b6d5',
#   -0.04733782634139061),
#  ('https://www.semanticscholar.org/paper/6fb84d2666787fed79939a02be8c6d767f6da481',
#   -0.04878164082765579),
#  ('https://www.semanticscholar.org/paper/34f0175fd1c8be17744620396e638d926ab2af78',
#   -0.04993788152933121),
#  ('https://www.semanticscholar.org/paper/2e55bc3d36ac8ddb35192356c367f1d4e79c3408',
#   -0.0508241131901741),
#  ('https://www.semanticscholar.org/paper/3b861ae93b96c94b2c1cc170fccd1b48812a8de4',
#   -0.05243737995624542),
#  ('https://www.semanticscholar.org/paper/52b521283f604535f644f481a1338200d87f4609',
#   -0.055059902369976044),
#  ('https://www.semanticscholar.org/paper/3bc53b5b2088389ef52ecf983e78223f09e03906',
#   -0.07007674127817154)]
